# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
print("- - - -lib loaded - - - ")
# Out:
# - - - -lib loaded - - -

# %%
df_sp = pd.read_csv('../datas/sales_predictions.csv'); df_sp.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
df_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
g = sns.relplot(x="item_price", y="date", data=df_sp)
g.set_axis_labels("Prix de l'article","Date de vente"); 
plt.show();

# %%
df_sp2 = df_sp.sample(n=50)

# %%
g2 = sns.relplot(x="item_price", y="date", data=df_sp2, height=10, aspect=1.2)
g2.set_axis_labels("Prix de l'article", "Date de vente"); 
plt.show();

# %%
df_sp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 2605217 to 1233956
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            50 non-null     object
#  1   date_block_num  50 non-null     int64
#  2   shop_id         50 non-null     int64
#  3   item_id         50 non-null     int64
#  4   item_price      50 non-null     float64
#  5   item_cnt_day    50 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 2.7+ KB

# %%
df_sp2['date'] = pd.to_datetime(df_sp2['date'])

# %%
df_sp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 2605217 to 1233956
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            50 non-null     datetime64[ns]
#  1   date_block_num  50 non-null     int64
#  2   shop_id         50 non-null     int64
#  3   item_id         50 non-null     int64
#  4   item_price      50 non-null     float64
#  5   item_cnt_day    50 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(3)
# memory usage: 2.7 KB

# %%
g2 = sns.relplot(x="item_price", y="date", data=df_sp2, height=10, aspect=1.2)
g2.set_axis_labels("Prix de l'article", "Date de vente"); 
plt.show();

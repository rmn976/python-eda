# %%
#1)
# Un KPI est un indicateur qui permet de savoir si on va dans le bon sens. Il ne s'agit pas d'un chiffre uniquement pris, 
# mais d'un indicateur fusionnant différentes données qui comnibnées ensemble donne un indicateur (chiffré) pertinent pour 
# le contexte et le but recherché.

# %%
#2)
import pandas as pd 
import numpy as np

# %%
#3)
df = pd.read_csv('datas/resto_eval.csv')

# %%
#4) 
df.head(12)
# Out:
#     Unnamed: 0  order_id  quantity                              item_name  \
# 0            0         1         1           Chips and Fresh Tomato Salsa
# 1            1         1         1                                   Izze
# 2            2         1         1                       Nantucket Nectar
# 3            3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4            4         2         2                           Chicken Bowl
# 5            5         3         1                           Chicken Bowl
# 6            6         3         1                          Side of Chips
# 7            7         4         1                          Steak Burrito
# 8            8         4         1                       Steak Soft Tacos
# 9            9         5         1                          Steak Burrito
# 10          10         5         1                    Chips and Guacamole
# 11          11         6         1                   Chicken Crispy Tacos
#
# ...

# %%
#5)
df.shape
# Out:
# (4622, 6)

# %%
#6)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  3376 non-null   object
#  5   item_price          4522 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 216.8+ KB

# %%
#7)
df.describe()
# Out:
#         Unnamed: 0     order_id     quantity
# count  4622.000000  4622.000000  4622.000000
# mean   2310.500000   927.254868     1.075725
# std    1334.400802   528.890796     0.410186
# min       0.000000     1.000000     1.000000
# 25%    1155.250000   477.250000     1.000000
# 50%    2310.500000   926.000000     1.000000
# 75%    3465.750000  1393.000000     1.000000
# max    4621.000000  1834.000000    15.000000

# %%
#8)
df_byitem= df.groupby(["item_name"])
df_byitem.sum().sort_values('quantity', ascending=False)
# L'item le plus commandé est donc Chicken Bowl avec 761 quantité commandée
# Out:
#                                        Unnamed: 0  order_id  quantity
# item_name
# Chicken Bowl                              1779909    713926       761
# Chicken Burrito                           1238217    497303       591
# Chips and Guacamole                       1121773    449959       506
# Steak Burrito                              817795    328437       386
# Canned Soft Drink                          759990    304753       351
# Chips                                      518704    208004       230
# Steak Bowl                                 482721    193752       221
# Bottled Water                              439354    175944       211
# Chips and Fresh Tomato Salsa               250144    100419       130
# Canned Soda                                189915     76396       126
# Chicken Salad Bowl                         292292    117104       123
# Chicken Soft Tacos                         244891     98395       120
# ...

# %%
#9)
df['quantity'].sum()
# Il y a eu 4972 items commandés
# Out:
# 4972

# %%
#10)
df_nan = df[df['item_price'].notna()]
df_nan['item_price'].replace('$', '')
df_nan['CA'] = df_nan['quantity'] ** df_nan['item_price']
df_nan['CA'].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...
